# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\hp

# %%
import os

print(os.listdir())
# Out:
# ['.anaconda', '.antigravity', '.cache', '.cagent', '.claude', '.claude.json', '.conda', '.config', '.continuum', '.copilot', '.docker', '.dockerignore', '.gemini', '.git', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.matplotlib', '.texlive2026', '.virtual_documents', '.vscode', '.vscode-shared', 'Advanced python', 'Advanced python.5fbcc830-25ff-4dec-a6d1-a2a216e3c36d', 'Advanced python1', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'assignment.ipynb', 'Assignments', 'Clustering.csv', 'clustering_bivaraiate.png', 'Contacts', 'Cookies', 'covid 19 data analaysis', 'Customer Segmentation And Clustering.ipynb', 'DA2.csv', 'Desktop', 'DH2_to_DN2_sections.csv', 'DH2_to_DN2_students_starting_with_A.csv', 'Dockerfile', 'Documents', 'Downloads', 'Favorites', 'female_students_starting_with_A.csv', 'Fianlproject.ipynb', 'gc.json', 'IntelGraphicsProfiles', 'intro Dango.ipynb', 'Links', 'Local Settings', 'MachineLearning.ipynb', 'Music', 'My Docume
# ...

# %%
df = pd.read_csv("realdatasets.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].median(), inplace=True)

df["CREDIT_LIMIT"].fillna(df["CREDIT_LIMIT"].median(), inplace=True)

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df_cluster = df.drop("CUST_ID", axis=1)

# %%
df_cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['BALANCE','PURCHASES','CREDIT_LIMIT','CASH_ADVANCE']

for feature in features:
    plt.figure(figsize=(8,4))
    sns.kdeplot(df[feature], fill=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

# %%
df.hist(figsize=(18,15), bins=30)
plt.suptitle('Histograms of All Features')
plt.show()

# %%
columns = ['BALANCE', 'PURCHASES', 'CASH_ADVANCE']

for i in columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(y=df[i])
    plt.title(f'Boxplot of {i}')
    plt.show()

# %%
df['INSTALLMENTS_PURCHASES'].value_counts(normalize=True)
# Out:
# INSTALLMENTS_PURCHASES
# 0.00      0.437542
# 300.00    0.001564
# 200.00    0.001564
# 100.00    0.001564
# 150.00    0.001341
#             ...
# 276.62    0.000112
# 590.76    0.000112
# 945.46    0.000112
# 414.48    0.000112
# 144.40    0.000112
# Name: proportion, Length: 4452, dtype: float64

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='BALANCE',
    y='PURCHASES'
)

plt.title('Balance vs Purchases')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='CREDIT_LIMIT',
    y='PURCHASES'
)

plt.title('Credit Limit vs Purchases')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='CASH_ADVANCE',
    y='BALANCE'
)

plt.title('Cash Advance vs Balance')
plt.show()

# %%
selected_columns = [
    'BALANCE',
    'PURCHASES',
    'CREDIT_LIMIT',
    'CASH_ADVANCE'
]

sns.pairplot(df[selected_columns])

plt.show()

# %%
df[['BALANCE',
    'PURCHASES',
    'CASH_ADVANCE',
    'CREDIT_LIMIT',
    'PAYMENTS']].mean()
# Out:
# BALANCE         1564.474828
# PURCHASES       1003.204834
# CASH_ADVANCE     978.871112
# CREDIT_LIMIT    4494.282473
# PAYMENTS        1733.143852
# dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# ...

# %%
features = df[['ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'PURCHASES_FREQUENCY']]

plt.figure(figsize=(8,5))
sns.heatmap(features.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # clustering - Univariate, Bivariate, Multivariate

# %%
clustering1 = KMeans()

# %%
clustering1.fit(df[['PURCHASES']])
# Out:
# KMeans()

# %%
clustering1.labels_
# Out:
# array([0, 0, 5, ..., 0, 0, 5], shape=(8950,), dtype=int32)

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE', 'Credit_Level'],
#       dtype='object')

# %%
clustering1.inertia_
# Out:
# 1398405224.6950622

# %%
intertia_scores=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(df[['PURCHASES']])
    intertia_scores.append(kmeans.inertia_)

# %%
intertia_scores
# Out:
# [40854048102.23442,
#  20280706765.381676,
#  9553427232.950235,
#  5357333247.685724,
#  3568918308.248686,
#  2857786981.6560903,
#  1815055293.435852,
#  1395841024.9837866,
#  1119617547.0648546,
#  947122067.0845755]

# %%
plt.plot(range(1,11),intertia_scores)

# %%
clustering1 = KMeans(n_clusters=3)

# %%
clustering1.fit(df[['PURCHASES']])
# Out:
# KMeans(n_clusters=3)

# %%
clustering1.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(8950,), dtype=int32)

# %%
df['Purchases Cluster'] = clustering1.labels_
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                    0.000000                          0.083333  ...
# ...

# %%
print(df.columns.tolist())
# Out:
# ['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE', 'Credit_Level', 'Balance cluster and Purchasing Cluster', 'Purchases Cluster']

# %%
df['Purchases Cluster'] = clustering1.labels_
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                    0.000000                          0.083333  ...
# ...

# %%
df['Purchases Cluster'].value_counts()
# Out:
# Purchases Cluster
# 0    8208
# 1     718
# 2      24
# Name: count, dtype: int64

# %%
clustering1.inertia_
# Out:
# 9553596685.471151

# %%
intertia_scores=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(df[['PURCHASES']])
    intertia_scores.append(kmeans.inertia_)

# %%
intertia_scores
# Out:
# [40854048102.23442,
#  20281563282.381073,
#  9553596685.471151,
#  5360432150.400618,
#  3570159959.423855,
#  2558687069.7665424,
#  2374781651.5235357,
#  1406750173.4578137,
#  1131711511.4495344,
#  953550119.0727224]

# %%
df.columns

# %%
df.dtypes

# %% [markdown]
# # Bivariate Clustering

# %%
clustering2 = KMeans(n_clusters=5)

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE', 'Credit_Level',
#        'Balance cluster and Purchasing Cluster'],
#       dtype='object')

# %%
clustering2 = KMeans(n_clusters=5)
clustering2.fit(df[['BALANCE','PURCHASES']])
df['Balance cluster and Purchasing Cluster'] =clustering2.labels_
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE', 'Credit_Level',
#        'Balance cluster and Purchasing Cluster'],
#       dtype='object')

# %%
intertia_scores2=[]
for i in range(1,11):
    kmeans2=KMeans(n_clusters=i)
    kmeans2.fit(df[['BALANCE','PURCHASES']])
    intertia_scores2.append(kmeans2.inertia_)
plt.plot(range(1,11),intertia_scores2)

# %%
canters=pd.DataFrame(clustering2.cluster_centers_)
centers
# Out:
#              x             y
# 0   819.457945    400.060824
# 1  5766.719525    810.299588
# 2  3879.930206   8799.320455
# 3  1166.798357   2979.087933
# 4  5728.549230  28601.207727

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=centers['x'],y=centers['y'],s=100, color='black',marker='*')
sns.scatterplot(data=df, x ='BALANCE',y='PURCHASES',hue='Balance cluster and Purchasing Cluster', palette='tab10')
# Out:
# <Axes: xlabel='BALANCE', ylabel='PURCHASES'>

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE', 'Credit_Level',
#        'Balance cluster and Purchasing Cluster'],
#       dtype='object')

# %%
pd.crosstab(df['Balance cluster and Purchasing Cluster'],df['Credit_Level'],normalize='index')
# Out:
# Credit_Level                                 Low    Medium      High
# Balance cluster and Purchasing Cluster
# 0                                       0.566343  0.427184  0.006472
# 1                                       0.967051  0.032614  0.000335
# 2                                       0.166667  0.666667  0.166667
# 3                                       0.777336  0.218688  0.003976
# 4                                       0.950712  0.048740  0.000548

# %% [markdown]
# # Multivariate Clustering

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                    0.000000                          0.083333  ...
# ...

# %%
dff = pd.get_dummies(df)
dff.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
dff.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY',
#        ...
#        'CUST_ID_C19184', 'CUST_ID_C19185', 'CUST_ID_C19186', 'CUST_ID_C19187',
#        'CUST_ID_C19188', 'CUST_ID_C19189', 'CUST_ID_C19190',
#        'Credit_Level_Low', 'Credit_Level_Medium', 'Credit_Level_High'],
#       dtype='object', length=8972)

# %%
dff = dff[['BALANCE', 'PURCHASES', 'CASH_ADVANCE','Credit_Level_Medium', 'Credit_Level_High']]
dff.head()
# Out:
#        BALANCE  PURCHASES  CASH_ADVANCE  Credit_Level_Medium  \
# 0    40.900749      95.40      0.000000                False
# 1  3202.467416       0.00   6442.945483                False
# 2  2495.148862     773.17      0.000000                False
# 3  1666.670542    1499.00    205.788017                False
# 4   817.714335      16.00      0.000000                False
#
#    Credit_Level_High
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %%
dff = scale.fit_transform(dff)

# %%
dff = pd.DataFrame(scale.fit_transform(dff))
dff.head()
# Out:
#           0         1         2         3        4
# 0 -0.731989 -0.424900 -0.466786 -0.285377 -0.03814
# 1  0.786961 -0.469552  2.605605 -0.285377 -0.03814
# 2  0.447135 -0.107668 -0.466786 -0.285377 -0.03814
# 3  0.049099  0.232058 -0.368653 -0.285377 -0.03814
# 4 -0.358775 -0.462063 -0.466786 -0.285377 -0.03814

# %%
intertia_scores5=[]
for i in range(1,11):
    kmeans5=KMeans(n_clusters=i)
    kmeans5.fit(dff)
    intertia_scores5.append(kmeans5.inertia_)
plt.plot(range(1,11),intertia_scores5)

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.to_csv('Clustering.csv')
